# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import pickle as pkl
import sys
import seaborn as sns

from fastFM import als
from fastFM.datasets import make_user_item_regression
from scipy.sparse import csc_matrix, hstack, vstack
from sklearn.preprocessing import MultiLabelBinarizer, OneHotEncoder, LabelEncoder
from sklearn.metrics import accuracy_score, roc_auc_score, mean_absolute_error
from hyperopt import tpe, fmin, hp, Trials, STATUS_OK
from collections import OrderedDict

% matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ### Import data

# %%
# import full data
data_path = os.path.join('..', 'data-2')
splits_path = os.path.join(data_path,'splits')
sparse_path = os.path.join(data_path, 'sparse')
columns = ['user','item','rating']

with open(os.path.join(splits_path, 'train.df'), 'rb') as file_in:
    train_df = pkl.load(file_in)
    
with open(os.path.join(splits_path, 'dev.df'), 'rb') as file_in:
    cv_df = pkl.load(file_in)
    
with open(os.path.join(splits_path, 'test.df'), 'rb') as file_in:
    test_df = pkl.load(file_in)
    
# import sparse data    
sparse = dict()
features = ['actors', 'country', 'directors-imdb', 'genres-amazon', 'genres-imdb', 'language', 'mpaa',
           'studios-amazon', 'studios-imdb', 'type', 'user-item']
for feature in features:
    with open(os.path.join(sparse_path, feature + '.dict'), 'rb') as file_in:
        sparse[feature] = pkl.load(file_in)
        
# import results from LSH and Baseline
results_lsh_train = pd.read_csv(os.path.join(data_path, 'results_lsh_train.csv'))
results_lsh_cv = pd.read_csv(os.path.join(data_path, 'results_lsh_cv.csv'))
results_lsh_test = pd.read_csv(os.path.join(data_path, 'results_lsh_test.csv'))

results_baseline_train = pd.read_csv(os.path.join(data_path, 'results_baseline_train.csv'))
results_baseline_cv = pd.read_csv(os.path.join(data_path, 'results_baseline_cv.csv'))
results_baseline_test = pd.read_csv(os.path.join(data_path, 'results_baseline_test.csv'))

train_df['pred_lsh'] = results_lsh_train['prediction'].values
train_df['pred_baseline'] = results_baseline_train['pred'].values

cv_df['pred_lsh'] = results_lsh_cv['prediction'].values
cv_df['pred_baseline'] = results_baseline_cv['pred'].values

test_df['pred_lsh'] = results_lsh_test['prediction'].values
test_df['pred_baseline'] = results_baseline_test['pred'].values

# %%
train_df
# Out:
#               item            user  rating  \
# 36684   6300214575   A1O60Q7LBN4MQ     4.0
# 307578  B005LAIIA8  A16IB3AQZQKKK0     5.0
# 1904    B004UXUX4Q   A3SS6VRWCTB7V     4.0
# 261125  B00005V1WW  A1TO1P3NV7OAU6     4.0
# 30998   6301404440  A1K3NQAO49LXL2     5.0
# 381514  0790731886  A11FX8HL2ANK6T     5.0
# 144812  B000M341QE  A1IWR4YH4ZA9BM     5.0
# 209178  B002VECM1S  A2CK0VXUDVXGMN     2.0
# 34212   6304744404   AAOF195P95ZVC     3.0
# 18321   B001UV4XHY   AT3NIL6Q0G44I     4.0
# 127645  6305627347  A3N5XIM9R2OQH0     5.0
# 306943  B00005JMWJ  A3Q1EDCBV2KU8D     3.0
# 4408    B0041KKYEM  A1XT8AJB7S9JJG     5.0
# 131240  0800100832  A2GEZJHBV92EVR     5.0
# 3296    079213690X  A26JGAM6GZMM4V     5.0
# 18321   Harry Potter and the Deathly Hallows: Part 1  294980434.0
# 127645            South Park: Bigger, Longer & Uncut          NaN
# 306943                          Welcome to Mooseport   14244145.0
# 4408                                      Black Swan  106952327.0
# 131240                         From Here to Eternity          NaN
# 3296                                      Braveheart          NaN
# 141629                              Cowboys & Aliens  100215116.0
# 81043      Star Wars: Episode I - The Phantom Menace  431000000.0
# 285287                                       Rampart     969239.0
# 61842                           Strangers on a Train          NaN
# 408019      House, M.D., Season Four: New Beginnings          NaN
# 202759                                  Jackie Brown          NaN
# 74981            The Hobbit: The Desolation of Smaug  180443783.0
# 161242                             Life Is Beautiful          NaN
# 242295                                             9   31691649.0
# 276880                                 A Mighty Wind   17475811.0
# 300971                          Godzilla: Final Wars          NaN
# 235266                                     The Lorax  213949505.0
# 236512                            Call Northside 777          NaN
# 342420                            A Day at the Races          NaN
# 155040                                       Airport          NaN
# ...                                              ...          ...
# 88069                                    Bleak House          NaN
# 178454                            The Eiger Sanction          NaN
# 323991                                    Unforgiven          NaN
# 35653                                         9 to 5          NaN
# 148016                               The Deer Hunter          NaN
# 395559                                    Brainstorm          NaN
# 331791                                  Black Sunday          NaN
# 210881                            30 Minutes or Less   37100000.0
# 164012                             Napoleon Dynamite   44478018.0
# 105222  Star Wars: Episode II - Attack of the Clones  307900000.0
# 65009                    Dragon: The Bruce Lee Story          NaN
# 140940                                    In the Cut    4717455.0
# 216055                                   The Patriot    2317507.0
# 207849                              28 Days Later...   44900469.0
# 34054                                 Mulholland Dr.          NaN
# 250740                               Mission to Mars          NaN
# 306177                   Around the World in 80 Days          NaN
# 49297                                  Jurassic Park   45299680.0
# 15989                                        Taken 2  139852115.0
# 18650             The Life Aquatic with Steve Zissou          NaN
# 101717                                 Groundhog Day          NaN
# 116700                                   Cabin Fever   21113424.0
# 141994                                  Bottle Shock    3939185.0
# 768                                       Predator 2          NaN
# 400018                            Godzilla vs. Gigan          NaN
# 384352                           Bill Cosby: Himself          NaN
# 375203                                     Brigadoon          NaN
# 141079                   He's Just Not That Into You   93800000.0
# 335622                                Young at Heart          NaN
# 76503                  The Girl Who Played with Fire    7638241.0
#
#                             country  \
# 36684                         [usa]
# 307578                        [usa]
# 1904                          [usa]
# 261125                        [usa]
# 30998                         [usa]
# 381514                        [usa]
# 144812             [usa, hong kong]
# 209178                 [usa, japan]
# 34212                     [uk, usa]
# 18321                     [uk, usa]
# 127645                        [usa]
# 306943               [usa, germany]
# 4408                          [usa]
# 131240                        [usa]
# 3296                          [usa]
# 141629                        [usa]
# 81043                         [usa]
# 285287                        [usa]
# 61842                         [usa]
# 408019                        [usa]
# 202759                        [usa]
# 74981            [usa, new zealand]
# 161242                      [italy]
# 242295                        [usa]
# 276880                        [usa]
# 300971    [japan, australia, china]
# 235266                [usa, france]
# 236512                        [usa]
# 342420                        [usa]
# 155040                        [usa]
# ...                             ...
# 88069                     [uk, usa]
# 178454                        [usa]
# 323991                        [usa]
# 35653                         [usa]
# 148016                    [usa, uk]
# 395559                        [usa]
# 331791                      [italy]
# 210881       [germany, canada, usa]
# 164012                        [usa]
# 105222                        [usa]
# 65009                         [usa]
# 140940         [uk, australia, usa]
# 216055               [usa, germany]
# 207849                         [uk]
# 34054                         [usa]
# 250740                        [usa]
# 306177  [usa, germany, ireland, uk]
# 49297                         [usa]
# 15989                 [france, usa]
# 18650                         [usa]
# 101717                        [usa]
# 116700                        [usa]
# 141994                        [usa]
# 768                           [usa]
# 400018                      [japan]
# 384352                        [usa]
# 375203                        [usa]
# 141079               [germany, usa]
# 335622                        [usa]
# 76503    [sweden, denmark, germany]
#
#                                                  language  metascore  \
# 36684                                           [english]        NaN
# 307578                                          [english]       74.0
# 1904                                            [english]       84.0
# 261125                                          [english]       25.0
# 30998                                           [english]       83.0
# 381514                                          [english]       69.0
# 144812                               [english, cantonese]       85.0
# 209178                                  [english, french]       57.0
# 34212                                    [english, latin]       35.0
# 18321                                           [english]       65.0
# 127645                                          [english]       73.0
# 306943                                          [english]       33.0
# 4408                           [english, french, italian]       79.0
# 131240                                          [english]        NaN
# 3296            [english, french, latin, scottish gaelic]       68.0
# 141629                        [english, apache languages]       50.0
# 81043                                           [english]       51.0
# 285287                                          [english]       70.0
# 61842                                   [english, french]        NaN
# 408019                                          [english]        NaN
# 202759                                          [english]       64.0
# 74981                                           [english]       66.0
# 161242                         [italian, german, english]       59.0
# 242295                                          [english]       60.0
# 276880                                          [english]       81.0
# 300971                     [cantonese, english, japanese]        NaN
# 235266                                          [english]       46.0
# 236512                                  [english, polish]        NaN
# 342420                                 [english, italian]        NaN
# 155040                                 [english, italian]       42.0
# ...                                                   ...        ...
# 88069                                           [english]        NaN
# 178454                                          [english]       61.0
# 323991                                          [english]       85.0
# 35653                                   [english, french]       58.0
# 148016             [english, russian, vietnamese, french]       81.0
# 395559                                          [english]        NaN
# 331791                                 [italian, english]        NaN
# 210881                         [english, german, spanish]       49.0
# 164012                                          [english]       64.0
# 105222                                          [english]       54.0
# 65009                                [english, cantonese]        NaN
# 140940                                          [english]       46.0
# 216055                                          [english]       63.0
# 207849                                 [english, spanish]       73.0
# 34054                                           [english]        NaN
# 250740                                          [english]       34.0
# 306177  [english, cantonese, french, german, hindi, tu...       49.0
# 49297                                  [english, spanish]       68.0
# 15989                          [english, turkish, arabic]       45.0
# 18650   [english, icelandic, filipino, portuguese, fre...       62.0
# 101717                         [english, french, italian]       72.0
# 116700                                          [english]       56.0
# 141994                          [english, french, german]       56.0
# 768                                             [english]        NaN
# 400018                                         [japanese]        NaN
# 384352                                          [english]        NaN
# 375203                                          [english]        NaN
# 141079                                          [english]       47.0
# 335622                                          [english]        NaN
# 76503                 [swedish, italian, english, french]       66.0
#
#        mpaa_rating  runtime     ...     imdb_votes  \
# 36684           PG     90.0     ...         4849.0
# 307578          PG     87.0     ...        81994.0
# 1904             R    115.0     ...       214728.0
# 261125       PG-13     87.0     ...        82150.0
# 30998           PG    104.0     ...       154844.0
# 381514          PG     97.0     ...        22718.0
# 144812           R    151.0     ...       972551.0
# 209178           R    120.0     ...        74681.0
# 34212            R     96.0     ...       131953.0
# 18321        PG-13    146.0     ...       373457.0
# 127645           R     81.0     ...       172884.0
# 306943       PG-13    110.0     ...        11117.0
# 4408             R    108.0     ...       599585.0
# 131240         NaN    118.0     ...        36605.0
# 3296             R    178.0     ...       815546.0
# 141629       PG-13    119.0     ...       184352.0
# 81043           PG    136.0     ...       590626.0
# 285287           R    108.0     ...        20989.0
# 61842           PG    101.0     ...       106469.0
# 408019         NaN     26.0     ...          131.0
# 202759           R    154.0     ...       260134.0
# 74981        PG-13    161.0     ...       528815.0
# 161242       PG-13    116.0     ...       482851.0
# 242295       PG-13     79.0     ...       118346.0
# 276880       PG-13     91.0     ...        23344.0
# 300971       PG-13    125.0     ...         5800.0
# 235266          PG     86.0     ...        83841.0
# 236512    APPROVED    112.0     ...         6768.0
# 342420      PASSED    111.0     ...        11328.0
# 155040           G    137.0     ...        14408.0
# ...            ...      ...     ...            ...
# 88069        TV-PG    510.0     ...         7282.0
# 178454           R    129.0     ...        14263.0
# 323991           R    130.0     ...       307578.0
# 35653           PG    109.0     ...        22067.0
# 148016           R    183.0     ...       257126.0
# 395559          PG    106.0     ...         9245.0
# 331791         NaN     87.0     ...        10787.0
# 210881           R     83.0     ...        82953.0
# 164012          PG     96.0     ...       172273.0
# 105222          PG    142.0     ...       516055.0
# 65009        PG-13    120.0     ...        23653.0
# 140940           R    119.0     ...        19531.0
# 216055           R    165.0     ...       223228.0
# 207849           R    113.0     ...       322956.0
# 34054          NaN     88.0     ...         3735.0
# 250740          PG    114.0     ...        63921.0
# 306177          PG    120.0     ...        74138.0
# 49297        PG-13    127.0     ...       693478.0
# 15989        PG-13     92.0     ...       256732.0
# 18650            R    119.0     ...       152880.0
# 101717          PG    101.0     ...       489181.0
# 116700           R     93.0     ...        66198.0
# 141994       PG-13    110.0     ...        13129.0
# 768              R    108.0     ...       118291.0
# 400018          PG     89.0     ...         2979.0
# 384352          PG    105.0     ...         3213.0
# 375203      PASSED    108.0     ...         6268.0
# 141079       PG-13    129.0     ...       140928.0
# 335622    APPROVED    117.0     ...         1843.0
# 76503            R    129.0     ...        79432.0
#
#                                directors        genres_amazon  \
# 36684                    [lynne littman]                   []
# 307578                      [tim burton]                   []
# 1904                   [alexander payne]              [drama]
# 261125                      [james wong]   [science, fiction]
# 30998                  [robert zemeckis]                   []
# 381514                    [steve gordon]             [comedy]
# 144812                 [martin scorsese]              [drama]
# 209178                    [nancy meyers]                   []
# 34212               [paul w.s. anderson]                   []
# 18321                      [david yates]                   []
# 127645                     [trey parker]                   []
# 306943                   [donald petrie]                   []
# 4408                  [darren aronofsky]                   []
# 131240                  [fred zinnemann]                   []
# 3296                        [mel gibson]                   []
# 141629                     [jon favreau]                   []
# 81043                     [george lucas]                   []
# 285287                   [oren moverman]                   []
# 61842                 [alfred hitchcock]  [mystery, thriller]
# 408019                              None                   []
# 202759               [quentin tarantino]                   []
# 74981                    [peter jackson]                   []
# 161242                 [roberto benigni]                   []
# 242295                     [shane acker]                   []
# 276880               [christopher guest]        [documentary]
# 300971                 [ryûhei kitamura]   [science, fiction]
# 235266        [chris renaud, kyle balda]                   []
# 236512                  [henry hathaway]                   []
# 342420                        [sam wood]                   []
# 155040   [george seaton, henry hathaway]                   []
# ...                                  ...                  ...
# 88069   [justin chadwick, susanna white]                   []
# 178454                  [clint eastwood]  [action, adventure]
# 323991                  [clint eastwood]            [western]
# 35653                    [colin higgins]                   []
# 148016                  [michael cimino]                   []
# 395559                [douglas trumbull]                   []
# 331791                      [mario bava]  [action, adventure]
# 210881                 [ruben fleischer]                   []
# 164012                      [jared hess]             [comedy]
# 105222                    [george lucas]                   []
# 65009                        [rob cohen]                   []
# 140940                    [jane campion]              [drama]
# 216055                 [roland emmerich]                   []
# 207849                     [danny boyle]                   []
# 34054                      [david lynch]            [romance]
# 250740                  [brian de palma]                   []
# 306177                    [frank coraci]                   []
# 49297                 [steven spielberg]                   []
# 15989                  [olivier megaton]                   []
# 18650                     [wes anderson]                   []
# 101717                    [harold ramis]                   []
# 116700                        [eli roth]                   []
# 141994                  [randall miller]                   []
# 768                    [stephen hopkins]                   []
# 400018                      [jun fukuda]                   []
# 384352                      [bill cosby]                   []
# 375203               [vincente minnelli]            [musical]
# 141079                      [ken kwapis]             [comedy]
# 335622                  [gordon douglas]                   []
# 76503                 [daniel alfredson]                   []
#
#                                                    actors  \
# 36684   [jane alexander, william devane, rossie harris...
# 307578  [winona ryder, catherine o'hara, martin short,...
# 1904                         [george clooney, judy greer]
# 261125  [jason statham, delroy lindo, carla gugino, je...
# 30998   [bob hoskins, christopher lloyd, joanna cassid...
# 381514  [dudley moore, liza minnelli, john gielgud, ge...
# 144812  [leonardo dicaprio, matt damon, jack nicholson...
# 209178                     [john krasinski, meryl streep]
# 34212   [laurence fishburne, sam neill, kathleen quinl...
# 18321   [daniel radcliffe, rupert grint, emma watson, ...
# 127645  [trey parker, matt stone, mary kay bergman, is...
# 306943  [gene hackman, ray romano, maura tierney, marc...
# 4408    [natalie portman, mila kunis, vincent cassel, ...
# 131240  [burt lancaster, montgomery clift, deborah ker...
# 3296    [mel gibson, sophie marceau, patrick mcgoohan,...
# 141629  [daniel craig, harrison ford, olivia wilde, sa...
# 81043   [ewan mcgregor, liam neeson, natalie portman, ...
# 285287  [woody harrelson, robin wright, steve buscemi,...
# 61842   [leo g. carroll, farley granger, patricia hitc...
# 408019  [hugh laurie, robert sean leonard, omar epps, ...
# 202759  [pam grier, samuel l. jackson, robert forster,...
# 74981                      [martin freeman, ian mckellen]
# 161242  [roberto benigni, nicoletta braschi, giorgio c...
# 242295  [christopher plummer, martin landau, john c. r...
# 276880  [catherine o'hara, parker posey, michael mckea...
# 300971  [don frye, masakatsu funaki, masatô ibu, shige...
# 235266  [danny devito, ed helms, zac efron, taylor swi...
# 236512  [james stewart, richard conte, lee j. cobb, he...
# 342420  [groucho marx, chico marx, harpo marx, allan j...
# 155040  [burt lancaster, dean martin, george kennedy, ...
# ...                                                   ...
# 88069   [gillian anderson, alun armstrong, charlie bro...
# 178454  [clint eastwood, george kennedy, vonetta mcgee...
# 323991  [clint eastwood, gene hackman, morgan freeman,...
# 210881      3.686818        3.756622    3.816266
# 164012      4.757154        4.755310    4.691918
# 105222      3.713421        3.415320    3.680459
# 65009       5.000000        5.277299    5.230289
# 140940      2.215005        2.781008    2.365254
# 216055      3.570478        3.704490    3.645190
# 207849      4.077410        4.491218    3.692737
# 34054       4.945573        4.607491    4.586759
# 250740      3.065262        2.401826    2.463369
# 306177      2.929161        2.873658    2.837636
# 49297       4.699244        3.371263    3.629556
# 15989       4.746008        4.990554    5.020973
# 18650       3.605555        3.682180    3.694192
# 101717      4.380478        4.236428    4.258552
# 116700      3.165844        2.989913    3.063411
# 141994      3.901948        3.982289    3.956215
# 768         3.908097        3.862968    3.788394
# 400018      4.674576        4.651620    4.623398
# 384352      4.846642        4.757112    4.756251
# 375203      3.583656        3.606554    3.705855
# 141079      2.875235        2.636668    2.262970
# 335622      5.000000        5.085205    5.036383
# 76503       4.025515        4.025693    4.032203
#
# [331561 rows x 26 columns]

# %% [markdown]
# ### Additional data cleaning

# %%
# convert years to ints
train_df['year'] = train_df['year'].apply(lambda x: x[0:4]).astype(int)
cv_df['year'] = cv_df['year'].apply(lambda x: x[0:4]).astype(int)
test_df['year'] = test_df['year'].apply(lambda x: x[0:4]).astype(int)

# %% [markdown]
# # Train and test using output from LSH and Baseline

# %%
test_df.head(2)
# Out:
#               item            user  rating       title  box_office  \
# 314030  B0002IQJ8W  A21XVS00AIENLX     4.0  Mean Girls    0.012681
# 336736  B009AMAOTQ  A3OVE04AUPODOT     5.0  Last Vegas   -0.329912
#
#               country                                language  metascore  \
# 314030  [usa, canada]  [english, german, vietnamese, swahili]   0.323330
# 336736          [usa]                               [english]  -0.670356
#
#        mpaa_rating   runtime      ...       \
# 314030       PG-13 -0.394437      ...
# 336736       PG-13 -0.167343      ...
#
#                                              studios_imdb  imdb_rating  \
# 314030    [paramount, picture, mg, film, broadway, video]          7.0
# 336736  [cbs, film, good, universe, laurence, mark, pr...          6.6
#
#         imdb_votes         directors genres_amazon  \
# 314030     0.51092     [mark waters]            []
# 336736    -0.18702  [jon turteltaub]            []
#
#                                                    actors  studios_amazon  \
# 314030  [lindsay lohan, jonathan bennett, rachel mcada...     [paramount]
# 336736                   [robert de niro, morgan freeman]     [cbs, film]
#
#        sales_rank  pred_lsh pred_baseline
# 314030  -0.365103  4.021510      4.324940
# 336736        NaN  4.360181      4.424858
#
# [2 rows x 24 columns]

# %%
def build_data(use_actors, use_country, use_directors, use_genres, use_language, use_mpaa, use_studios, use_type,
               use_scores, use_popularity, use_year, use_model_results):
    X_orig = dict(train=train_df, cv=cv_df, test=test_df)
    X = dict()
    y = dict()
    datasets = ['train', 'cv', 'test']
    for dataset in datasets:
        X[dataset] = sparse['user-item'][dataset]
        y[dataset] = X_orig[dataset]['rating']
    X['columns'] = list()

    sparse_features = list()
    dense_features = list()
    if use_actors: sparse_features.append('actors')
    if use_country: sparse_features.append('country')
    if use_directors: sparse_features.append('directors-imdb')
    if use_genres:
        sparse_features.extend(['genres-amazon','genres-imdb'])
        dense_features.append('vfx')
    if use_language: sparse_features.append('language')
    if use_mpaa: sparse_features.append('mpaa')
    if use_studios: sparse_features.extend(['studios-amazon','studios-imdb'])
    if use_type:
        sparse_features.append('type')
        dense_features.append('runtime')
    if use_scores: dense_features.extend(['metascore','imdb_rating'])
    if use_popularity: dense_features.extend(['imdb_votes','sales_rank','box_office'])
    if use_year: dense_features.append('year')
    if use_model_results: dense_features.extend(['pred_lsh', 'pred_baseline'])
    
    for feature in sparse_features:
        X['columns'] += list(sparse[feature]['columns'])
        for dataset in datasets:
            X[dataset] = hstack([X[dataset], sparse[feature][dataset]])
            
    for feature in dense_features:
        X['columns'].append(feature)
        for dataset in datasets:
            new_data = X_orig[dataset][feature]
            median = new_data.quantile(0.5)
            new_data = new_data.fillna(median).values
            new_data = new_data.reshape(X_orig[dataset].shape[0],-1)
            X[dataset] = hstack([X[dataset], new_data])
            
    return X, y

# %%
X_, y_ = build_data(use_actors=True, use_country=True, use_directors=True, use_genres=True,
                 use_language=True, use_mpaa=True, use_studios=True, use_type=True,
                 use_scores=True, use_popularity=True, use_year=True, use_model_results=True)

# %%
X_, y_ = build_data(use_actors=False, use_country=False, use_directors=False, use_genres=True,
                 use_language=False, use_mpaa=False, use_studios=False, use_type=False,
                 use_scores=False, use_popularity=False, use_year=False, use_model_results=True)

fm = als.FMRegression(n_iter=883,
                          rank=2,
                          init_stdev=0.4,
                          l2_reg_w=7.3,
                          l2_reg_V=1.5)

fm.fit(X_['train'], y_['train'])
y_cv_pred = fm.predict(X_['cv'])
print(mean_absolute_error(y_cv_pred, y_['cv']))
# Out:
# 0.730550124517

# %%
mean_absolute_error(np.clip(y_cv_pred, a_max=5, a_min=1), y_['cv'])
# Out:
# 0.72192410185889788

# %%
# define the objective function that the fmin module can later optimize on
def test_fm(params):
    print('==========TESTING FM==========')
    params['n_iter'] = int(params['n_iter'])
    params['rank'] = int(params['rank'])
    print(params)
    
    fm = als.FMRegression(n_iter=params['n_iter'],
                          rank=params['rank'],
                          init_stdev=params['init_stdev'],
                          l2_reg_w=params['l2_reg_w'],
                          l2_reg_V=params['l2_reg_V'])
    
    X, y = build_data(use_actors=params['use_actors'],
                      use_country=params['use_country'],
                      use_directors=params['use_directors'],
                      use_genres=params['use_genres'],
                      use_language=params['use_language'],
                      use_mpaa=params['use_mpaa'],
                      use_studios=params['use_studios'],
                      use_type=params['use_type'],
                      use_scores=params['use_scores'],
                      use_popularity=params['use_popularity'],
                      use_year=params['use_year'],
                      use_model_results=params['use_model_results'])

    # build model and evaluate
    fm.fit(X['train'], y['train'])
    y_cv_pred = fm.predict(X['cv'])
    mae = mean_absolute_error(y_cv_pred, y['cv'])
    print('MAE:', mae)
    return mae

# %%
use_pretrained = True

if use_pretrained:
    with open(os.path.join(data_path, 'trials_fm_external'), 'rb') as file_in:
        trials = pkl.load(file_in)
    with open(os.path.join(data_path, 'best_fm_external.dict'), 'rb') as file_in:
        best = pkl.load(file_in)
else:
    '''set the range of hyperparameters for the FM
    '''
    trials = Trials()
    space = {
        'n_iter': hp.uniform('n_iter', 100, 1000),
        'init_stdev': hp.uniform('init_stdev', 0, 1),
        'rank': hp.uniform('rank', 2, 6),
        'l2_reg_w': hp.uniform('l2_reg_w', 0, 21),
        'l2_reg_V': hp.uniform('l2_reg_V', 0, 21),
        'use_actors': hp.choice('use_actors', [False,True]),
        'use_country': hp.choice('use_country', [False,True]),
        'use_directors': hp.choice('use_directors', [False,True]),
        'use_genres': hp.choice('use_genres', [False,True]),
        'use_language': hp.choice('use_language', [False,True]),
        'use_mpaa': hp.choice('use_mpaa', [False,True]),
        'use_studios': hp.choice('use_studios', [False,True]),
        'use_type': hp.choice('use_type', [False,True]),
        'use_scores': hp.choice('use_scores', [False,True]),
        'use_popularity': hp.choice('use_popularity', [False,True]),
        'use_year': hp.choice('use_year', [False,True]),
        'use_model_results': hp.choice('use_model_results', [False,True])
    }
    
    # Choose the Tree-structured Parzen Estimator (TPE) as the algorithm to optimize the objective function
    best = fmin(algo = tpe.suggest,
               fn = test_fm,
               trials = trials,
               max_evals = 300, # max number of tests
               space = space)
    with open(os.path.join(data_path, 'trials_fm_external'), 'wb') as file_out:
        pkl.dump(trials, file_out)
    with open(os.path.join(data_path, 'best_fm_external.dict'), 'wb') as file_out:
        pkl.dump(best, file_out)
# Out:
# ==========TESTING FM==========
# {'init_stdev': 0.7869225950466535, 'l2_reg_V': 19.050805103823443, 'l2_reg_w': 4.92064101877817, 'n_iter': 304, 'rank': 3, 'use_actors': True, 'use_country': False, 'use_directors': False, 'use_genres': True, 'use_language': False, 'use_mpaa': False, 'use_popularity': True, 'use_scores': True, 'use_studios': True, 'use_type': True, 'use_year': False}
# MAE: 2.2910883472
# ==========TESTING FM==========
# {'init_stdev': 0.622960291130542, 'l2_reg_V': 2.9112399305925605, 'l2_reg_w': 15.811117090928366, 'n_iter': 663, 'rank': 2, 'use_actors': False, 'use_country': True, 'use_directors': False, 'use_genres': False, 'use_language': True, 'use_mpaa': False, 'use_popularity': True, 'use_scores': False, 'use_studios': False, 'use_type': False, 'use_year': True}
# MAE: 0.990856411405
# ==========TESTING FM==========
# {'init_stdev': 0.2627607847177368, 'l2_reg_V': 14.903734407150765, 'l2_reg_w': 5.74041436786561, 'n_iter': 216, 'rank': 5, 'use_actors': True, 'use_country': True, 'use_directors': True, 'use_genres': True, 'use_language': True, 'use_mpaa': True, 'use_popularity': True, 'use_scores': True, 'use_studios': True, 'use_type': False, 'use_year': True}
# MAE: 5.67922950448
# ==========TESTING FM==========
# {'init_stdev': 0.3826145500430357, 'l2_reg_V': 7.397056757487456, 'l2_reg_w': 2.1799863846682266, 'n_iter': 670, 'rank': 3, 'use_actors': True, 'use_country': True, 'use_directors': True, 'use_genres': True, 'use_language': False, 'use_mpaa': False, 'use_popularity': True, 'use_scores': False, 'use_studios': False, 'use_type': True, 'use_year': True}

# %%
fm = als.FMRegression(n_iter=200, init_stdev=0.1, rank=3, l2_reg_w=7, l2_reg_V=7)
fm.fit(X_train, y_train)
y_pred = fm.predict(X_test)

# %%
mean_absolute_error(y_pred, y_test)
# Out:
# 0.72999601412891579
